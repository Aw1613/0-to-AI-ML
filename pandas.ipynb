# %% [markdown]
# # Pandas tutorial
# Most of the time will be spend on reading the data instead of making it

# %% [markdown]
# ### DataFrames and series
# We can think of like multiple series makes up the DataFrames and we write it like this

# %%
import pandas as pd
dataset = pd.DataFrame({'Food':['4 Apple','3 beetroot'],
                        'Armour':['Chestplate','Iron helmet'],
                        'Weapons':['1 sword','4 axe']} )
dataset
# Out:
#          Food       Armour  Weapons
# 0     4 Apple   Chestplate  1 sword
# 1  3 beetroot  Iron helmet    4 axe

# %%
seriesdemo = pd.Series([4,8,2,8,9,2,1,0], index = [1,2,3,4,5,6,7,8], name = 'Random series')
seriesdemo
# Out:
# 1    4
# 2    8
# 3    2
# 4    8
# 5    9
# 6    2
# 7    1
# 8    0
# Name: Random series, dtype: int64

# %% [markdown]
# ## loc and iloc
# the major diffrence between them is that loc can fetch the labels of string and intigers but the loc can only fetch intigeral values
# so when we know the index of both row and column then iloc can be helpfull but in the most case of big data set loc is going to help us most
#
# and the loc works on stdlib of python format like when i say [0:10 ] then this would fetch values form 0....9 but for the loc it will do 0.....10 so total 11 values of which we need to take care of

# %% [markdown]
# ## 6.
# There are only so many words you can use when describing a bottle of wine. Is a wine more likely to be "tropical" or "fruity"? Create a Series `descriptor_counts` counting how many times each of these two words appears in the `description` column in the dataset. (For simplicity, let's ignore the capitalized versions of these words.)
#
# https://www.kaggle.com/code/aw1613/exercise-summary-functions-and-maps/edit
# link to question

# %%
fruti_c = reviews.description.map(lambda p : 'fruity' in p )
fruti_n = fruti_c.sum()
tropi_c = reviews.description.map(lambda p : 'tropical' in p )
tropi_n = tropi_c.sum()
descriptor_counts = pd.Series([tropi_n,fruti_n], index =['tropical','fruity'])

# %% [markdown]
# ### The approach in solving it
# we do stepwise solution and tell whole one row what it has to do rather than handeling each and every single data point by ourselves
#
# here we first made a series of true and false if frutiy thing exist in our description or not by using the map function to make it into series and by using the sum we counted it how many times it was true and did the same for the tropical wine too
#
# at last made a series to place the result of the data values

# %% [markdown]
# ## 7.
# We'd like to host these wine reviews on our website, but a rating system ranging from 80 to 100 points is too hard to understand - we'd like to translate them into simple star ratings. A score of 95 or higher counts as 3 stars, a score of at least 85 but less than 95 is 2 stars. Any other score is 1 star.
#
# Also, the Canadian Vintners Association bought a lot of ads on the site, so any wines from Canada should automatically get 3 stars, regardless of points.
#
# Create a series `star_ratings` with the number of stars corresponding to each review in the dataset.

# %%
def rating(rows):
    if rows.country == 'Canada':
        return  3
    if rows.points >= 95:
        return 3
    elif rows.points >= 85 and rows.points <95:
        return 2
    else:
        return 1
star_ratings = reviews.apply(rating, axis='columns')

# Check your answer
q7.check()

# %% [markdown]
# ### What made me wonder
# when i am returning things iw will totally depend on what i am returning , i am returning a row then it will all get collectd and return the data type as dataFrame \
# And if i return a single value , it will form a series with each specific row
#
# and here the apply function takes complete row and return rating for a specific row as it moves form top to down (columns as mentioned)
