# %% [markdown]
# # Notes of Basic python course
# Only important aspects noted down here

# %% [markdown]
# ### list question
# 5. 🌶️¶
# We're using lists to record people who attended our party and what order they arrived in. For example, the following list represents a party with 7 guests, in which Adela showed up first and Ford was the last to arrive:
#
# party_attendees = ['Adela', 'Fleda', 'Owen', 'May', 'Mona', 'Gilbert', 'Ford']
# A guest is considered 'fashionably late' if they arrived after at least half of the party's guests. However, they must not be the very last guest (that's taking it too far). In the above example, Mona and Gilbert are the only guests who were fashionably late.
#
# Complete the function below which takes a list of party attendees as well as a person, and tells us whether that person is fashionably late.

# %%
def fashionably_late(arrivals, name):
    """Given an ordered list of arrivals to the party and a name, return whether the guest with that
    name was fashionably late.
    """
    # write the code here
    # https://www.kaggle.com/code/aw1613/exercise-lists/edit
    # link to solution

# %% [markdown]
# ### Loops
# we can use loops in string also and here is a an example of it too

# %%
s = 'steganograpHy is the practicE of conceaLing a file, message, image, or video within another fiLe, message, image, Or video.'
for char in s:
    if char.isupper():
        print(char , end = '')
# Out:
# HELLO

# %% [markdown]
# ### List comprenhshion
# unique most featue , here are some examples

# %%
sq = [n**2 for n in range(10)]
print(sq)
# combined condition in the list only otherwise we would have done something like this
squares = []
for n in range(10):
    squares.append(n**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# conditions can also be inserted too in that 
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
short_planets = [planet for planet in planets if (len(planet) < 6)]
short_planets
# Out:
# ['Venus', 'Earth', 'Mars']

# %% [markdown]
# people generally write in diffrent lines to make it claeraly understandable to others
# it increases the readiablity

# %%
# .upper() converts all the charachter of the string into uppercase 
loud_short_planets = [
                        planet.upper() + '!' 
                        for planet in planets 
                        if len(planet) < 6
                        ]
print(loud_short_planets)
#otherwise the thing in the bracket would look like [planet.upper() + '!' for planet in planets if len(planet) < 6]
[32 for planet in planets]
# value_is_this for iterator in list 
# this is the analogy where planet is used as the iterator to point the value on the list but there is 32 instead of the planet that is why 32x5
# Out:
# ['VENUS!', 'EARTH!', 'MARS!']
# [32, 32, 32, 32, 32, 32, 32, 32]

# %% [markdown]
# check the last examples of the list comprehnsion of the length of the code was minimized
# https://www.kaggle.com/code/colinmorris/loops-and-list-comprehensions

# %%
help(any)
# Out:
# Help on built-in function any in module builtins:
#
# any(iterable, /)
#     Return True if bool(x) is True for any x in the iterable.
#
#     If the iterable is empty, return False.

# %% [markdown]
# ### Strings
# There are some usefull function for the string and their name suggest there work
# 1. .upper()
# 2. .lower()
# 3. .startswith()
# 4. .endswith()
# 5. .index()
#
# and while concatinating the string using "+" then we need to make sure that non string objects must be under str()

# %%
planet = "pluto"
pos = 9
print("{} is the {}th planet in the solar system".format(planet,pos))

pluto_mass = 1.303 * 10**22
earth_mass = 5.9722 * 10**24
population = 52910390
#         2 decimal points   3 decimal points, format as percent     separate with commas
print("{} weighs about {:.2} kilograms ({:.3%} of Earth's mass). It is home to {:,} Plutonians.".format(
    planet, pluto_mass, pluto_mass / earth_mass, population,
))

# Referring to format() arguments by index, starting from 0
s = """Pluto's a {0}.
No, it's a {1}.
{0}!
{1}!""".format('planet', 'dwarf planet')
print(s)
# Out:
# pluto is the 9th planet in the solar system
# pluto weighs about 1.3e+22 kilograms (0.218% of Earth's mass). It is home to 52,910,390 Plutonians.
# Pluto's a planet.
# No, it's a dwarf planet.
# planet!
# dwarf planet!

# %% [markdown]
# ### Dictionaries
# some dictonaries using method

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
planet_to_initial = {planet: planet[0] for planet in planets}
print(planet_to_initial)

# Get all the initials, sort them alphabetically, and put them in a space-separated string.
print(' '.join(sorted(planet_to_initial.values())))

for planet, initial in planet_to_initial.items():
    print("{} begins with \"{}\"".format(planet.rjust(10), initial))
    # used .rjust() to right allign the planets name
# Out:
# {'Mercury': 'M', 'Venus': 'V', 'Earth': 'E', 'Mars': 'M', 'Jupiter': 'J', 'Saturn': 'S', 'Uranus': 'U', 'Neptune': 'N'}
# E J M M N S U V
#    Mercury begins with "M"
#      Venus begins with "V"
#      Earth begins with "E"
#       Mars begins with "M"
#    Jupiter begins with "J"
#     Saturn begins with "S"
#     Uranus begins with "U"
#    Neptune begins with "N"
